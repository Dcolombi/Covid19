# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib
import scipy

# %%
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from pylab import rcParams
from pandas.api.types import CategoricalDtype
from datetime import date, timedelta
import warnings
import folium
from folium.plugins import HeatMap
import pandas_profiling
import math
import seaborn as sns
print('matplotlib: {}'.format(matplotlib.__version__))
# Out:
# matplotlib: 3.1.3

# %%
import glob

glued_data = pd.DataFrame()
for file_name in glob.glob('./dati-province/'+'*.csv'):
    x = pd.read_csv(file_name, low_memory=False)
    glued_data = pd.concat([glued_data,x],axis=0)

# %%
glued_data[glued_data.denominazione_provincia=='Milano']
# Out:
#                      data stato  codice_regione denominazione_regione  \
# 55    2020-02-29 17:00:00   ITA               3             Lombardia
# 55    2020-02-28 18:00:00   ITA               3             Lombardia
# 55    2020-03-15 17:00:00   ITA               3             Lombardia
# 55    2020-03-01 17:00:00   ITA               3             Lombardia
# 55    2020-03-14 17:00:00   ITA               3             Lombardia
# 55    2020-03-02 17:00:00   ITA               3             Lombardia
# 55    2020-03-16 17:00:00   ITA               3             Lombardia
# 55    2020-03-17 17:00:00   ITA               3             Lombardia
# 55    2020-03-03 17:00:00   ITA               3             Lombardia
# 55    2020-03-07 18:00:00   ITA               3             Lombardia
# 55    2020-03-13 17:00:00   ITA               3             Lombardia
# 55    2020-03-12 17:00:00   ITA               3             Lombardia
# 55    2020-03-06 18:00:00   ITA               3             Lombardia
# 55    2020-02-24 18:00:00   ITA               3             Lombardia
# 183   2020-02-25 18:00:00   ITA               3             Lombardia
# 311   2020-02-26 18:00:00   ITA               3             Lombardia
# 439   2020-02-27 18:00:00   ITA               3             Lombardia
# 567   2020-02-28 18:00:00   ITA               3             Lombardia
# 695   2020-02-29 17:00:00   ITA               3             Lombardia
# 823   2020-03-01 17:00:00   ITA               3             Lombardia
# 951   2020-03-02 17:00:00   ITA               3             Lombardia
# 1079  2020-03-03 17:00:00   ITA               3             Lombardia
# 1207  2020-03-04 17:00:00   ITA               3             Lombardia
# 1335  2020-03-05 17:00:00   ITA               3             Lombardia
# 1463  2020-03-06 18:00:00   ITA               3             Lombardia
# 1591  2020-03-07 18:00:00   ITA               3             Lombardia
# 1719  2020-03-08 18:00:00   ITA               3             Lombardia
# 1847  2020-03-09 18:00:00   ITA               3             Lombardia
# 1975  2020-03-10 18:00:00   ITA               3             Lombardia
# 2103  2020-03-11 17:00:00   ITA               3             Lombardia
# 2231  2020-03-12 17:00:00   ITA               3             Lombardia
# 2359  2020-03-13 17:00:00   ITA               3             Lombardia
# 2487  2020-03-14 17:00:00   ITA               3             Lombardia
# 2615  2020-03-15 17:00:00   ITA               3             Lombardia
# 2743  2020-03-16 17:00:00   ITA               3             Lombardia
# 2871  2020-03-17 17:00:00   ITA               3             Lombardia
# 2999  2020-03-18 17:00:00   ITA               3             Lombardia
# 3127  2020-03-19 17:00:00   ITA               3             Lombardia
# 3255  2020-03-20 17:00:00   ITA               3             Lombardia
# 3383  2020-03-21 17:00:00   ITA               3             Lombardia
# 3511  2020-03-22 17:00:00   ITA               3             Lombardia
# 3639  2020-03-23 17:00:00   ITA               3             Lombardia
# 55    2020-03-23 17:00:00   ITA               3             Lombardia
# 55    2020-03-10 18:00:00   ITA               3             Lombardia
# 55    2020-03-04 17:00:00   ITA               3             Lombardia
# 55    2020-03-05 17:00:00   ITA               3             Lombardia
# 55    2020-03-11 17:00:00   ITA               3             Lombardia
# 55    2020-03-08 18:00:00   ITA               3             Lombardia
# 55    2020-03-20 17:00:00   ITA               3             Lombardia
# 55    2020-03-21 17:00:00   ITA               3             Lombardia
# 55    2020-03-09 18:00:00   ITA               3             Lombardia
# 55    2020-03-23 17:00:00   ITA               3             Lombardia
# 55    2020-03-22 17:00:00   ITA               3             Lombardia
# 55    2020-03-19 17:00:00   ITA               3             Lombardia
# 55    2020-03-18 17:00:00   ITA               3             Lombardia
# 55    2020-02-25 18:00:00   ITA               3             Lombardia
# 55    2020-02-24 18:00:00   ITA               3             Lombardia
# 55    2020-02-26 18:00:00   ITA               3             Lombardia
# 55    2020-02-27 18:00:00   ITA               3             Lombardia
#
#       codice_provincia denominazione_provincia sigla_provincia        lat  \
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 183                 15                  Milano              MI  45.466794
# 311                 15                  Milano              MI  45.466794
# 439                 15                  Milano              MI  45.466794
# 567                 15                  Milano              MI  45.466794
# 695                 15                  Milano              MI  45.466794
# 823                 15                  Milano              MI  45.466794
# 951                 15                  Milano              MI  45.466794
# 1079                15                  Milano              MI  45.466794
# 1207                15                  Milano              MI  45.466794
# 1335                15                  Milano              MI  45.466794
# 1463                15                  Milano              MI  45.466794
# 1591                15                  Milano              MI  45.466794
# 1719                15                  Milano              MI  45.466794
# 1847                15                  Milano              MI  45.466794
# 1975                15                  Milano              MI  45.466794
# 2103                15                  Milano              MI  45.466794
# 2231                15                  Milano              MI  45.466794
# 2359                15                  Milano              MI  45.466794
# 2487                15                  Milano              MI  45.466794
# 2615                15                  Milano              MI  45.466794
# 2743                15                  Milano              MI  45.466794
# 2871                15                  Milano              MI  45.466794
# 2999                15                  Milano              MI  45.466794
# 3127                15                  Milano              MI  45.466794
# 3255                15                  Milano              MI  45.466794
# 3383                15                  Milano              MI  45.466794
# 3511                15                  Milano              MI  45.466794
# 3639                15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
# 55                  15                  Milano              MI  45.466794
#
#           long  totale_casi
# 55    9.190347         30.0
# 55    9.190347         29.0
# 55    9.190347       1750.0
# 55    9.190347         46.0
# 55    9.190347       1551.0
# 55    9.190347         58.0
# 55    9.190347       1983.0
# 55    9.190347       2326.0
# 55    9.190347         93.0
# 55    9.190347        361.0
# 55    9.190347       1307.0
# 55    9.190347       1146.0
# 55    9.190347        267.0
# 55    9.190347          0.0
# 183   9.190347          8.0
# 311   9.190347          8.0
# 439   9.190347         15.0
# 567   9.190347         29.0
# 695   9.190347         30.0
# 823   9.190347         46.0
# 951   9.190347         58.0
# 1079  9.190347         93.0
# 1207  9.190347        145.0
# 1335  9.190347        197.0
# 1463  9.190347        267.0
# 1591  9.190347        361.0
# 1719  9.190347        406.0
# 1847  9.190347        506.0
# 1975  9.190347        592.0
# 2103  9.190347        925.0
# 2231  9.190347       1146.0
# 2359  9.190347       1307.0
# 2487  9.190347       1551.0
# 2615  9.190347       1750.0
# 2743  9.190347       1983.0
# 2871  9.190347       2326.0
# 2999  9.190347       2644.0
# 3127  9.190347       3278.0
# 3255  9.190347       3804.0
# 3383  9.190347       4672.0
# 3511  9.190347       5096.0
# 3639  9.190347       5326.0
# 55    9.190347       5326.0
# 55    9.190347        592.0
# 55    9.190347        145.0
# 55    9.190347        197.0
# 55    9.190347        925.0
# 55    9.190347        406.0
# 55    9.190347       3804.0
# 55    9.190347       4672.0
# 55    9.190347        506.0
# 55    9.190347       5326.0
# 55    9.190347       5096.0
# 55    9.190347       3278.0
# 55    9.190347       2644.0
# 55    9.190347          8.0
# 55    9.190347          0.0
# 55    9.190347          8.0
# 55    9.190347         15.0

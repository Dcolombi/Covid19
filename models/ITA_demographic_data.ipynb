# %%
import pandas as pd

# %% [markdown]
# # Age groups in Italy

# %%
dfs = pd.read_excel("./WPP2019_POP_F07_1_POPULATION_BY_AGE_BOTH_SEXES.xlsx", sheet_name='ESTIMATES',
                    index=['Index'],header=[1])

# %%
italy_df = dfs[(dfs['Region, subregion, country or area *']=='Italy') &
              (dfs['Reference date (as of 1 July)']==2020)]

# %%
italy_df
# Out:
#       Index    Variant Region, subregion, country or area * Notes  \
# 3554   3555  Estimates                                Italy   NaN
#
#       Country code          Type  Parent code  Reference date (as of 1 July)  \
# 3554           380  Country/Area          925                           2020
#
#           0-4     5-9  ...    55-59    60-64   65-69   70-74    75-79  \
# 3554  2324.69  2670.3  ...  4658.95  3953.57  3531.3  3391.8  2637.11
#
#         80-84    85-89    90-94    95-99    100+
# 3554  2302.39  1397.26  639.739  172.639  16.517
#
# [1 rows x 29 columns]

# %%
italy_sel = italy_df[['Region, subregion, country or area *',
       '0-4', '5-9', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39',
       '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70-74', '75-79',
       '80-84', '85-89', '90-94', '95-99', '100+']]

# %%
italy_sel.rename(columns={'Region, subregion, country or area *': 'country'}, inplace=True)
# Out:
# /Users/davide/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
italy_ag = italy_sel.unstack().reset_index(name='value')\
                    .rename(columns={'level_0': 'age_groups', 'value': 'Population'}).iloc[1:]

# %%
italy_ag = italy_ag.drop('level_1', axis=1)

# %%
italy_ag.head()
# Out:
#   age_groups Population
# 1        0-4    2324.69
# 2        5-9     2670.3
# 3      10-14    2857.36
# 4      15-19    2876.09
# 5      20-24    2942.51

# %%
italy_ag = italy_ag[:-5].append({'age_groups' : '80+' , 'Population' : italy_ag[-5:].Population.sum()} , ignore_index=True)

# %%
italy_ag['Population'] = italy_ag['Population']*1000.

# %%
italy_ag
# Out:
#    age_groups   Population
# 0         0-4  2.32469e+06
# 1         5-9   2.6703e+06
# 2       10-14  2.85736e+06
# 3       15-19  2.87609e+06
# 4       20-24  2.94251e+06
# 5       25-29  3.16093e+06
# 6       30-34  3.36551e+06
# 7       35-39  3.63292e+06
# 8       40-44  4.18898e+06
# 9       45-49  4.83302e+06
# 10      50-54  4.90825e+06
# 11      55-59  4.65895e+06
# 12      60-64  3.95357e+06
# 13      65-69   3.5313e+06
# 14      70-74   3.3918e+06
# 15      75-79  2.63711e+06
# 16        80+  4.52855e+06

# %%
italy_ag.to_csv('Italian_population_per_age.csv')

# %% [markdown]
# # Contact matrices

# %%
'''home =  pd.read_excel("./Contat_matrices/contact_matrices_152_countries/MUestimates_home_1.xlsx", 
                         sheet_name='Italy')
school =  pd.read_excel("./Contat_matrices/contact_matrices_152_countries/MUestimates_school_1.xlsx", 
                         sheet_name='Italy')
work =  pd.read_excel("./Contat_matrices/contact_matrices_152_countries/MUestimates_work_1.xlsx", 
                         sheet_name='Italy')
others =  pd.read_excel("./Contat_matrices/contact_matrices_152_countries/MUestimates_other_locations_1.xlsx", 
                         sheet_name='Italy')'''
# Out:
# 'home =  pd.read_excel("./Contat_matrices/contact_matrices_152_countries/MUestimates_home_1.xlsx", \n                         sheet_name=\'Italy\')\nschool =  pd.read_excel("./Contat_matrices/contact_matrices_152_countries/MUestimates_school_1.xlsx", \n                         sheet_name=\'Italy\')\nwork =  pd.read_excel("./Contat_matrices/contact_matrices_152_countries/MUestimates_work_1.xlsx", \n                         sheet_name=\'Italy\')\nothers =  pd.read_excel("./Contat_matrices/contact_matrices_152_countries/MUestimates_other_locations_1.xlsx", \n                         sheet_name=\'Italy\')'

# %%
standard_contacts = pd.read_csv('./Contat_matrices/20200324145954_social_contact_matrix.csv')

# %%
standard_contacts
# Out:
#    age_group  contact_[0,5)  contact_[5,10)  contact_[10,15)  contact_[15,20)  \
# 0      [0,5)       3.478473        1.116026         0.297388         0.193122
# 1     [5,10)       1.134844        9.123083         1.662754         0.255659
# 2    [10,15)       0.291381        1.602156        14.619724         1.482606
# 3    [15,20)       0.182631        0.237761         1.430967        16.746679
# 4    [20,25)       0.550160        0.251400         0.487329         1.369417
# 5    [25,30)       0.270087        0.314767         0.323973         0.794921
# 6    [30,35)       0.754400        0.632884         0.339174         0.366296
# 7    [35,40)       0.841023        0.839904         0.467134         0.558689
# 8    [40,45)       0.647053        1.044146         0.995537         0.902478
# 9    [45,50)       0.807757        0.682799         0.729972         1.517324
# 10   [50,55)       0.274612        0.688370         1.903011         1.683560
# 11   [55,60)       0.450159        0.772238         0.732263         0.437057
# 12   [60,65)       0.417111        0.327792         0.580200         0.375378
# 13   [65,70)       0.323678        0.376054         0.289078         0.143424
# 14   [70,75)       0.355441        0.224310         0.267974         0.141042
# 15   [75,80)       0.132592        0.226896         0.107076         0.387909
# 16       80+       0.392226        0.423886         0.376476         0.433799
#
#     contact_[20,25)  contact_[25,30)  contact_[30,35)  contact_[35,40)  \
# 0          0.631750         0.370564         1.244903         1.462545
# 1          0.293552         0.439148         1.061987         1.485227
# 2          0.548299         0.435518         0.548397         0.795943
# 3          1.487081         1.031397         0.571621         0.918785
# 4          4.946697         3.410796         1.387714         1.069173
# 5          2.854650         3.336159         2.465497         1.778677
# 6          0.965657         2.049889         2.553654         2.278818
# 7          0.705998         1.403315         2.162429         3.044802
# 8          0.922534         1.089738         1.715060         2.629179
# 9          0.967220         0.953355         1.349183         1.757421
# 10         0.959103         1.105447         1.232140         1.400037
# 11         0.797349         1.121736         1.096534         1.186773
# 12         0.650148         0.926885         1.421869         1.300382
# 13         0.205360         0.450784         0.924359         1.064755
# 14         0.388079         0.569916         0.349962         0.635604
# 15         0.118758         0.344933         0.099421         0.378425
# 16         0.401164         1.170414         0.655669         0.465582
#
#     contact_[40,45)  contact_[45,50)  contact_[50,55)  contact_[55,60)  \
# 0          1.103045         1.211635         0.380688         0.632830
# 1          1.809991         1.041467         0.970363         1.103910
# 2          1.662836         1.072840         2.584818         1.008618
# 3          1.454897         2.152342         2.207097         0.581033
# 4          1.369553         1.263454         1.157867         0.976142
# 5          1.353991         1.042283         1.116937         1.149350
# 6          1.771736         1.226388         1.035087         0.934135
# 7          2.577342         1.515880         1.116062         0.959373
# 8          3.104735         1.729641         1.777114         1.028118
# 9          1.965707         1.544041         1.498099         1.244584
# 10         2.185336         1.620992         1.654044         1.575029
# 11         1.246738         1.327987         1.553166         1.829993
# 12         1.376487         1.011260         1.144802         1.549088
# 13         0.765140         0.638415         0.534623         0.805385
# 14         1.049309         0.584333         0.478492         0.714117
# 15         0.655470         0.704673         0.548300         0.752115
# 16         0.595849         0.972469         1.030561         1.590815
#
#     contact_[60,65)  contact_[65,70)  contact_[70,75)  contact_[75,80)  \
# 0          0.493241         0.389267         0.366959         0.113732
# 1          0.394156         0.459882         0.235483         0.197905
# 2          0.672240         0.340633         0.271070         0.089991
# 3          0.419777         0.163117         0.137702         0.314659
# 4          0.669519         0.215077         0.348910         0.088710
# 5          0.798866         0.395133         0.428845         0.215647
# 6          1.018905         0.673661         0.218946         0.051679
# 7          0.884255         0.736347         0.377341         0.186658
# 8          0.954831         0.539787         0.635476         0.329813
# 9          0.797223         0.511855         0.402179         0.402963
# 10         0.976535         0.463801         0.356347         0.339263
# 11         1.303055         0.688997         0.524442         0.458914
# 12         0.999825         1.378111         0.711533         0.377829
# 13         1.355057         1.212253         0.693821         0.693805
# 14         0.814992         0.808226         0.356957         0.612198
# 15         0.520877         0.972756         0.736840         0.244714
# 16         1.177330         0.843241         0.473299         0.276103
#
#     contact_80+
# 0      0.147612
# 1      0.162216
# 2      0.138822
# 3      0.154388
# 4      0.131477
# 5      0.321044
# 6      0.149532
# 7      0.100758
# 8      0.131543
# 9      0.243988
# 10     0.279774
# 11     0.425875
# 12     0.374692
# 13     0.263877
# 14     0.172532
# 15     0.121140
# 16     0.435048

# %% [markdown]
# # Elaboration of national data from Protezione Civile

# %%
import glob

glued_data = pd.DataFrame()
for file_name in glob.glob('./dati-andamento-nazionale/'+'*.csv'):
    x = pd.read_csv(file_name, low_memory=False)
    glued_data = pd.concat([glued_data,x],axis=0)

# %%
glued_data.sort_values('data', inplace=True)

# %%
glued_data.columns
# Out:
# Index(['data', 'stato', 'ricoverati_con_sintomi', 'terapia_intensiva',
#        'totale_ospedalizzati', 'isolamento_domiciliare',
#        'totale_attualmente_positivi', 'nuovi_attualmente_positivi',
#        'dimessi_guariti', 'deceduti', 'totale_casi', 'tamponi'],
#       dtype='object')

# %%
glued_data.plot('data', 'deceduti')

# %%
glued_data.to_csv('italian_data.csv')

# %% [markdown]
# # Dati per Regione

# %%
import glob

glued_data = pd.DataFrame()
for file_name in glob.glob('./dati-regioni/'+'*.csv'):
    x = pd.read_csv(file_name, low_memory=False)
    glued_data = pd.concat([glued_data,x],axis=0)

# %%
glued_data.sort_values('data', inplace=True)

# %%
glued_data
# Out:
#                     data stato  codice_regione denominazione_regione  \
# 7    2020-02-24 18:00:00   ITA              12                 Lazio
# 1    2020-02-24 18:00:00   ITA              17            Basilicata
# 2    2020-02-24 18:00:00   ITA               4          P.A. Bolzano
# 4    2020-02-24 18:00:00   ITA              15              Campania
# 5    2020-02-24 18:00:00   ITA               8        Emilia Romagna
# ..                   ...   ...             ...                   ...
# 591  2020-03-23 17:00:00   ITA              18              Calabria
# 590  2020-03-23 17:00:00   ITA               4          P.A. Bolzano
# 589  2020-03-23 17:00:00   ITA              17            Basilicata
# 597  2020-03-23 17:00:00   ITA               3             Lombardia
# 20   2020-03-23 17:00:00   ITA               5                Veneto
#
#            lat       long  ricoverati_con_sintomi  terapia_intensiva  \
# 7    41.892770  12.483667                       1                  1
# 1    40.639471  15.805148                       0                  0
# 2    46.499335  11.356624                       0                  0
# 4    40.839566  14.250850                       0                  0
# 5    44.494367  11.341721                      10                  2
# ..         ...        ...                     ...                ...
# 591  38.905976  16.594402                      82                 20
# 590  46.499335  11.356624                     145                 33
# 589  40.639471  15.805148                      15                 12
# 597  45.466794   9.190347                    9266               1183
# 20   45.434905  12.338452                    1206                281
#
#      totale_ospedalizzati  isolamento_domiciliare  \
# 7                       2                       0
# 1                       0                       0
# 2                       0                       0
# 4                       0                       0
# 5                      12                       6
# ..                    ...                     ...
# 591                   102                     178
# 590                   178                     510
# 589                    27                      62
# 597                 10449                    8461
# 20                   1487                    3499
#
#      totale_attualmente_positivi  nuovi_attualmente_positivi  dimessi_guariti  \
# 7                              2                           2                1
# 1                              0                           0                0
# 2                              0                           0                0
# 4                              0                           0                0
# 5                             18                          18                0
# ..                           ...                         ...              ...
# 591                          280                          20                5
# 590                          688                          40                7
# 589                           89                           8                0
# 597                        18910                        1025             6075
# 20                          4986                         342              327
#
#      deceduti  totale_casi  tamponi
# 7           0            3      124
# 1           0            0        0
# 2           0            0        1
# 4           0            0       10
# 5           0           18      148
# ..        ...          ...      ...
# 591         7          292     4073
# 590        29          724     6084
# 589         1           90      696
# 597      3776        28761    73242
# 20        192         5505    61115
#
# [1239 rows x 16 columns]

# %%
glued_data.to_csv('italian_regional_data.csv')
